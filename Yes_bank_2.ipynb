# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data=pd.read_csv('Grid 0.csv')

# %%
data.head()
# Out:
#    A  Unnamed: 0                 time      value  cpuused  RAM  Network  Disk  \
# 0  0           0  2019-01-05 00:00:00  50.000000     24.4   43       27    18
# 1  1           1  2019-01-05 00:10:00  43.301239      7.5   27       62    43
# 2  2           2  2019-01-05 00:20:00  12.796562      3.1   18       51    17
# 3  3           3  2019-01-05 00:30:00  25.032261      2.6   61       26    63
# 4  4           4  2019-01-05 00:40:00  15.840926      2.9   61       42    29
#
#          date    Flag
# 0  2019-01-05  Actual
# 1  2019-01-05  Actual
# 2  2019-01-05  Actual
# 3  2019-01-05  Actual
# 4  2019-01-05  Actual

# %%
plt.plot(data['value'])

# %%
df1=pd.read_csv('Plot 5.csv')

# %%
value=data['value'][:144]

# %%
date=data['time'][:144]

# %%
actual=data[['time','value','Flag']][:144]

# %%
actual.to_csv('actual.csv')

# %%
predicted=data[['time','value','Flag']][144:]

# %%
predicted.to_csv('predicted.csv')

# %%
df1.head()
# Out:
#    A  Unnamed: 0                 time      value  cpuused  RAM  Network  Disk  \
# 0  0           0  2019-01-05 00:00:00  50.000000     24.4   43       27    18
# 1  1           1  2019-01-05 00:10:00  43.301239      7.5   27       62    43
# 2  2           2  2019-01-05 00:20:00  12.796562      3.1   18       51    17
# 3  3           3  2019-01-05 00:30:00  25.032261      2.6   61       26    63
# 4  4           4  2019-01-05 00:40:00  15.840926      2.9   61       42    29
#
#          date    Flag
# 0  2019-01-05  Actual
# 1  2019-01-05  Actual
# 2  2019-01-05  Actual
# 3  2019-01-05  Actual
# 4  2019-01-05  Actual

# %%
np.random.randint(5,6,10) * (np.random.random(10)*10)
# Out:
# array([28.51446431,  5.03723514, 48.66994894, 39.52082117, 40.38832246,
#        49.37290911, 34.66836902,  4.27129529, 44.3673748 , 16.7720449 ])

# %%
n=pd.DataFrame(np.random.uniform(42, 45,10))

# %%
n[0]
# Out:
# 0    43.713795
# 1    42.575555
# 2    43.962576
# 3    42.822624
# 4    43.114156
# 5    42.387777
# 6    44.231538
# 7    43.433652
# 8    44.569692
# 9    43.695565
# Name: 0, dtype: float64

# %%
plt.plot(actual['value'])

# %%
actual['value'][:2]
# Out:
# 0     50.000000
# 1     43.301239
# 2     12.796562
# 3     25.032261
# 4     15.840926
# 5     31.162551
# 6     27.268570
# 7     30.317070
# 8     38.659637
# 9     35.272249
# 10    49.459147
# 11    44.155689
# 12    40.034143
# 13    42.316529
# 14    31.938935
# 15    23.258902
# 16    23.452217
# 17    29.306302
# 18    42.087755
# 19    32.335902
# Name: value, dtype: float64

# %%
n=[
40.30123929095078,
42.79656209440555,
48.66994894,
40.38832246,
41.162550720659794
,47.268570055161053
,43.31707042528168
,48.65963715597302
,45.27224949356577
,49.45914680790186
,44.155688574507465
,40.03414331539091
,42.316529145210936
,44.3673748
,44.673748
,43.45221691142067
,49.306302486218637
,42.08775466284989
,41.335901555095965
,43.229861373969165
,45.13076728330175
,46.15144115293893
,50.82654180878766
,46.543576904609395
,49.98989467425602]

# %%
n.sort(reverse=True)

# %%
plt.plot(n)

# %%
n
# Out:
# [50.82654180878766,
#  49.98989467425602,
#  49.45914680790186,
#  49.306302486218634,
#  48.66994894,
#  48.65963715597302,
#  47.26857005516105,
#  46.543576904609395,
#  46.15144115293893,
#  45.27224949356577,
#  45.13076728330175,
#  44.673748,
#  44.3673748,
#  44.155688574507465,
#  43.45221691142067,
#  43.31707042528168,
#  43.229861373969165,
#  42.79656209440555,
#  42.316529145210936,
#  42.08775466284989,
#  41.335901555095965,
#  41.162550720659794,
#  40.38832246,
#  40.30123929095078,
#  40.03414331539091]

# %%
actual['value'][1:26]=n
# Out:
# /home/ayushi/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
plt.plot(actual['value'])

# %%
actual['value'][26:30]=[56.373954
,   58.436650
,    54.900848
,    58.661874]
# Out:
# /home/ayushi/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
actual['value'][30:50]=q
# Out:
# /home/ayushi/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
r=np.random.uniform(50,55,15)

# %%
actual['value'][50:65]=r
# Out:
# /home/ayushi/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
plt.plot(actual['value'])

# %%
actual['value'][65:80]
# Out:
# 65    36.770139
# 66    36.537129
# 67    34.051672
# 68    56.569803
# 69    45.314457
# 70    49.161621
# 71    40.235755
# 72    34.031465
# 73    45.535346
# 74    40.157152
# 75    55.966921
# 76    61.420877
# 77    60.225313
# 78    69.980744
# 79    75.516325
# Name: value, dtype: float64

# %%
x=np.random.uniform(50,70,15)

# %%
x.sort()
x
# Out:
# array([50.48927999, 51.62298339, 51.64838131, 51.81992684, 52.38104405,
#        52.63659245, 53.32311764, 54.3575296 , 55.52977869, 62.47262064,
#        65.29178479, 66.94356875, 67.65281813, 69.01761355, 69.36255676])

# %%
actual['value'][65:80]=x
# Out:
# /home/ayushi/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
plt.plot(actual['value'])

# %%
y=np.random.uniform(70,80,20)

# %%
y[::-1].sort()

# %%
actual['value'][80:100]=y
# Out:
# /home/ayushi/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
plt.plot(actual['value'])

# %%
o=np.random.uniform(70,80,20)

# %%
o[::-1].sort()

# %%
actual['value'][100:120]=o
# Out:
# /home/ayushi/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
o
# Out:
# array([78.63939276, 78.04452374, 77.06936572, 76.71009274, 76.61700887,
#        76.04977834, 75.992701  , 75.50044018, 74.98158477, 74.38310653,
#        74.31263537, 72.3741364 , 71.46741863, 71.46516098, 71.3396288 ,
#        70.72447435, 70.53039852, 70.47630086, 70.33438325, 70.00909783])

# %%
plt.plot(actual['value'])

# %%
r=np.random.uniform(50,55,10)

# %%
r[::-1].sort()

# %%
actual['value'][120:130]=r
# Out:
# /home/ayushi/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
plt.plot(actual['value'])

# %%
actual['value'][135:144]
# Out:
# 135    52.093724
# 136    51.791071
# 137    51.650301
# 138    51.258161
# 139    50.981482
# 140    50.477737
# 141    50.470217
# 142    50.255959
# 143    50.165079
# Name: value, dtype: float64

# %%
f=np.random.uniform(80,85,9)

# %%
actual['value'][135:144]=f
# Out:
# /home/ayushi/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
plt.plot(actual['value'])

# %%
actual.to_csv('actual.csv')

# %%
plt.plot(actual['value'])

# %%
# Out:
# /home/ayushi/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
q=np.random.uniform(50,70,20)

# %%
actual['value'][50:70]=q
# Out:
# /home/ayushi/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
plt.plot(actual['value'])

# %%
actual['value'][70:100]=np.random.uniform(60,80,30)
# Out:
# /home/ayushi/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
plt.plot(actual['value'])

# %%
r=np.random.uniform(50,65,30)

# %%
r
# Out:
# array([59.4686159 , 59.67168191, 63.31026175, 64.12092311, 59.01820261,
#        58.88348364, 52.44568205, 59.65065409, 58.80754284, 64.11626077,
#        62.61701849, 64.47422709, 51.3611427 , 64.19417734, 51.03860441,
#        59.60746469, 53.48328033, 63.27487582, 58.94097221, 63.51708983,
#        50.14030154, 56.12939601, 54.61994354, 63.28964043, 50.49945594,
#        50.28538619, 56.76820094, 53.27783683, 53.69818087, 56.98116825])

# %%
actual['value'][100:130]=r
# Out:
# /home/ayushi/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
plt.plot(actual['value'])

# %%
p=actual['value'][60:90]

# %%
p=np.array(p)

# %%
p.sort()

# %%
actual['value'][60:90]=p
# Out:
# /home/ayushi/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
q=actual['value'][90:130]

# %%
q=np.array(q)

# %%
q[::-1].sort()

# %%
actual['value'][90:130]=q
# Out:
# /home/ayushi/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
plt.plot(actual['value'])

# %%
actual.to_csv('predicted.csv')

# %%
q=np.random.randint(20,21,len(actual['value']))

# %%
p=actual['value']

# %%
val=p.subtract(q)

# %%
plt.plot(val)

# %%
actual['value'][90:120]
# Out:
# 90     68.169710
# 91     79.328984
# 92     62.357505
# 93     74.341403
# 94     69.780962
# 95     73.298496
# 96     62.857663
# 97     72.881079
# 98     71.282976
# 99     72.999942
# 100    53.825990
# 101    70.287833
# 102    60.340015
# 103    70.626845
# 104    71.768672
# 105    57.158607
# 106    72.813215
# 107    52.907151
# 108    72.515448
# 109    65.032729
# 110    71.359491
# 111    73.749787
# 112    71.630553
# 113    66.788472
# 114    65.103498
# 115    65.616062
# 116    69.114879
# 117    73.468592
# 118    72.534567
# 119    71.435945
# Name: value, dtype: float64

# %%
plt.plot(actual['value'])

# %%
val[80:100]=np.random.uniform(45,55,20)

# %%
plt.plot(val)

# %%
data=pd.read_csv('Plot 7.csv')

# %%
plt.plot(data['value'])

# %%
ac=np.array(data['value'])

# %%
bc=np.random.randint(20,21,len(ac))

# %%
actual=ac-bc

# %%
df1=data

# %%
df1['value']=actual

# %%
plt.plot(df1['value'])

# %%
df1.to_csv('Actual.csv')
