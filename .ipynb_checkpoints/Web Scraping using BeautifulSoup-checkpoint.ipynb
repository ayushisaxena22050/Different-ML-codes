# %%
import requests
import bs4
import pandas as pd
import numpy as np

# %%
res=requests.get("https://www.metalbulletin.com/SearchResults.aspx#?term=rebar&onlyCurrent")

# %%
type(res)
result=res.text

# %%
soup1=bs4.BeautifulSoup(result,"html.parser")
type(soup1)
# Out:
# bs4.BeautifulSoup

# %%
<span class="headline-intro ng-binding" ng-bind-html="article|resultContent"><p>Eastern China’s Shagang has increased the prices for its long steel products for orders booked in the first 20 days of February.</p></span>

# %%
data = soup1.findAll('span',attrs={'class':'headline-intro ng-binding','ng-bind-html':'article|resultContent'})
# for div in data:
#     links = div.findAll('a')
#     for a in links:
#         tab=a['href']

# %%
for sentence in soup1.select("#articleText p"):

# %%
second_sentence = soup1.p.find_all_next(text=True)

for item in second_sentence:
    print(item.split('\n'))
# Out:
# ['', '\t\t\t\tCOPYING AND DISTRIBUTING ARE PROHIBITED WITHOUT THE PERMISSION OF THE PUBLISHER', '\t\t\t']
# ['', '']
# ['', '']
# ['', '']
# ['window.dataLayer = window.dataLayer || []; dataLayer.push({"website_name":"website desktop","ga_account":"UA-113890-1","page_type":"search result","page_name":"/ga-virtual/search-result","logged_in":"not logged in"});']
# [' Google Tag Manager ']
# ["(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start': new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src='//www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);})(window,document,'script','dataLayer','GTM-K22LFG');"]
# [' End Google Tag Manager ']
# ['window.euromoney = window.euromoney || {}; window.euromoney.dataLayer = {"timeout":60000,"isGaEnabled":true}']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['Welcome to Fastmarkets MB now']
# ['incorporating Steel First']
# ['', '']
# ['All Steel First prices, news and market analysis can be found here on www.metalbulletin.com']
# ['', '']
# ['', '']
# ['', '']
# ['More information and FAQs']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['\r', '@media screen {\r', '#scF5DN\r', '{top: 47%; position: fixed; z-index: 999999;}\r', '}\r', '@media print {\r', '#scF5DN\r', '{visibility: hidden; height: 0px; float: left;}\r', '}\r', '']
# ['\r', "adestraDomain = 'metalbulletin.msgfocus.com';\r", '']
# ['', '']
# ['', '']
# ['', '']
# ['[if gt IE 6]><!']
# ['', '']
# ['', '']
# [' test2 ']
# [' ']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['[if gt IE 6]><!']
# ['', '']
# ['[if gt IE 6]><!']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['document.write("<div><span>Cookie Information:&#160;</span><div>In common with most websites, this site uses cookies to carry out various tasks including improving our users\' experience.<br><br>Cookies are pieces of information which include a unique reference code that a website transfers to your device.<br><br>For information about your cookie options including turning them off,&#160;<a href=\'/Cookies.html\'>click here</a>.<br><br>To carry on with cookies running, click <b>proceed</b> or click the X to close this window and continue browsing. You can review your cookie options at any time by clicking on the Cookies link at the foot of each page</div></div>")']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '            googletag.cmd.push(function()', '            {', '            googletag.display("div-gpt-ad-41505eb4dc9741feab58bcf6f20d6e16");', '            });', '            ']
# ['', '']
# ['', '']
# ['', '']
# ['', '            googletag.cmd.push(function()', '            {', '            googletag.display("div-gpt-ad-c04612e969f5419287eb33163830e322");', '            });', '            ']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '\t\t\t\tMore ']
# ['', '']
# ['', '']
# ['', '']
# ['Store']
# ['', '']
# ['Fastmarkets AMM']
# ['', '']
# ['Fastmarkets MB Research']
# ['', '']
# ['Fastmarkets MB Events']
# ['', '']
# ['Training']
# ['', '']
# ['Fastmarkets MB Iron Ore Index']
# ['', '']
# ['Fastmarkets MB Database']
# ['', '']
# ['FastMarkets']
# ['', '']
# ['Fastmarkets IM']
# ['', '']
# ['Sponsored Content']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['Products']
# ['', '']
# ['About us']
# ['', '']
# ['Contact us']
# ['', '']
# ['FAQs']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '', '  if (!window.MB) {', '    window.MB = {};', '  }', '  ', '  if (!window.search) {', '    window.search = {};', '  }', '  ', "  window.search.searchApiUrl = 'https://search.euromoneyapi.com';", "  window.search.subscription = 'NotLoggedIn';", '  ', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '\t\t\tFree Trial ']
# ['', '']
# ['', '']
# ['', '\t\t\tSubscribe ']
# ['', '']
# ['', '']
# ['', '\t\t\tLog in ']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['TOP MENU']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['Non-ferrous']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['Non-ferrous']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['Base metals']
# ['', '']
# ['', '']
# ['', '']
# ['Ores & alloys']
# ['', '']
# ['', '']
# ['', '']
# ['Raw materials']
# ['', '']
# ['', '']
# ['', '']
# ['Minor metals']
# ['', '']
# ['', '']
# ['', '']
# ['Scrap & secondary']
# ['', '']
# ['', '']
# ['', '']
# ['Precious metals']
# ['', '']
# ['', '']
# ['', '']
# ['Battery raw materials']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['Base metals']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['Base metals']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['Aluminium']
# ['Copper']
# ['Lead']
# ['Nickel']
# ['Tin']
# ['Zinc']
# ['Base metals price guide']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '\tLatest news']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['LIVE FUTURES REPORT 01/02: SHFE base metals prices rangebound ahead of China’s week-long holiday']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['Feb 1, 2019 @ 04:30', '\t\t\t\t\t']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['LIVE FUTURES REPORT 31/01: LME base metals tick higher on positive trade sentiment; copper closes above $6,100']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['Jan 31, 2019 @ 18:58', '\t\t\t\t\t']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['LIVE FUTURES REPORT 31/01: Comex copper extends rally, US stocks up']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['Jan 31, 2019 @ 15:36', '\t\t\t\t\t']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '\t\t\t\t\tMore news', '\t\t\t\t\t']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['Ores & alloys']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['Ores & alloys']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['Bulk ores & alloys']
# ['Chrome']
# ['Ferro-nickel']
# ['Ferro-silicon']
# ['Manganese ores & alloys']
# ['', '']
# ['', '']
# ['Noble ores & alloys']
# ['Ferro-titanium']
# ['Molybdenum']
# ['Tungsten']
# ['Vanadium']
# ['Ores & alloys price guide']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '\tLatest news']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['BATTERY RAW MATERIALS MARKET REPORT 25/01: Cobalt price slide slows below $20 per lb watermark']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['Jan 25, 2019 @ 20:32', '\t\t\t\t\t']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['BATTERY RAW MATERIALS MARKET REPORT 18/01: Cobalt supply availability pushes price lower']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['Jan 18, 2019 @ 17:49', '\t\t\t\t\t']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '\t\t\t\t\tMore news', '\t\t\t\t\t']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['Raw materials']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['Raw materials']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['Alumina']
# ['Aluminium scrap']
# ['Raw materials price guide']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '\tLatest news']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['FOCUS: Zinc’s 2019 price prospects hinge on Chinese smelting bottleneck ']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['Jan 31, 2019 @ 11:20', '\t\t\t\t\t']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['Bushveld rides vanadium wave to strong 2018 profits']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['Jan 31, 2019 @ 02:35', '\t\t\t\t\t']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ["Vale's dam failure will not influence decision on Alunorte, sources say"]
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['Jan 30, 2019 @ 17:30', '\t\t\t\t\t']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '\t\t\t\t\tMore news', '\t\t\t\t\t']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['Minor metals']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['Minor metals']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['Antimony']
# ['Arsenic']
# ['Bismuth']
# ['Cadmium']
# ['Chromium']
# ['Cobalt']
# ['Gallium']
# ['Germanium']
# ['Hafnium']
# ['Indium']
# ['', '']
# ['', '']
# ['Magnesium']
# ['Manganese']
# ['Mercury']
# ['Rhenium']
# ['Selenium']
# ['Silicon']
# ['Tellurium']
# ['Titanium']
# ['Minor metals price guide']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '\tLatest news']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['US ferro-titanium major says no impact on output from fire']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['Jan 31, 2019 @ 12:25', '\t\t\t\t\t']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['MINOR METALS MARKET REPORT 30/01: Bismuth finds support; selenium continues downtrend']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['Jan 30, 2019 @ 17:27', '\t\t\t\t\t']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '\t\t\t\t\tMore news', '\t\t\t\t\t']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['Scrap & secondary']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['Scrap & secondary']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['Scrap & secondary price guide']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '\tLatest news']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['DAILY SCRAP REPORT: Prices inch down on more bookings ']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['Jan 31, 2019 @ 16:12', '\t\t\t\t\t']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['European molybdenum markets extend gains']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['Jan 31, 2019 @ 15:30', '\t\t\t\t\t']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['US ferro-titanium major says no impact on output from fire']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['Jan 31, 2019 @ 12:25', '\t\t\t\t\t']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '\t\t\t\t\tMore news', '\t\t\t\t\t']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['Precious metals']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['Precious metals']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['All precious metals']
# ['Precious metals price guide']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '\tLatest news']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['LIVE FUTURES REPORT 31/01: Comex copper extends rally, US stocks up']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['Jan 31, 2019 @ 15:36', '\t\t\t\t\t']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['METALS MORNING VIEW 31/01: Metals’ price rallies gain momentum']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['Jan 31, 2019 @ 09:25', '\t\t\t\t\t']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['LIVE FUTURES REPORT 30/01: Positive trade sentiment lifting base metals']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['Jan 30, 2019 @ 15:37', '\t\t\t\t\t']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '\t\t\t\t\tMore news', '\t\t\t\t\t']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['Battery raw materials']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['Battery raw materials']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['Lithium']
# ['Cobalt']
# ['Nickel']
# ['Manganese']
# ['Graphite']
# ['Vanadium']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '\tLatest news']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['Trade log January 2019: Lithium ']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['Jan 31, 2019 @ 17:06', '\t\t\t\t\t']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['Neometals lithium spodumene production down 15% in Oct-Dec 2018']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['Jan 30, 2019 @ 18:05', '\t\t\t\t\t']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['Trade log January 2019: Cobalt ']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['Jan 30, 2019 @ 17:59', '\t\t\t\t\t']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '\t\t\t\t\tMore news', '\t\t\t\t\t']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['Steel']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['Steel']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['Flat products']
# ['', '']
# ['', '']
# ['', '']
# ['Long products']
# ['', '']
# ['', '']
# ['', '']
# ['Steel raw materials']
# ['', '']
# ['', '']
# ['', '']
# ['Semi finished products']
# ['', '']
# ['', '']
# ['', '']
# ['Stainless & Special steels']
# ['', '']
# ['', '']
# ['', '']
# ['Tube & pipe']
# ['', '']
# ['', '']
# ['', '']
# ['Supply chain & End users']
# ['', '']
# ['', '']
# ['', '']
# ['Industry']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['Flat products']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['Flat products']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['Hot Rolled Coil']
# ['Cold Rolled Coil']
# ['Coated steels']
# ['Plate']
# ['Electrical steels']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '\tLatest news']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['China AM: Coking coal, coke futures rise further']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['Feb 1, 2019 @ 06:15', '\t\t\t\t\t']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['EUROPE HDG: Domestic prices reach ‘bottom’']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['Jan 31, 2019 @ 16:45', '\t\t\t\t\t']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['CHINA HRC: Market stands still ahead of holiday ']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['Jan 31, 2019 @ 10:04', '\t\t\t\t\t']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '\t\t\t\t\tMore news', '\t\t\t\t\t']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['Long products']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['Long products']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['Rebar']
# ['Wire rod']
# ['Beams, Sections and Rails']
# ['Engineering Steels and SBQ']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '\tLatest news']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['China AM: Coking coal, coke futures rise further']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['Feb 1, 2019 @ 06:15', '\t\t\t\t\t']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['China’s Shagang raises long steel prices for early to mid-February']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['Feb 1, 2019 @ 03:28', '\t\t\t\t\t']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['IN CASE YOU MISSED IT: 5 key stories from January 31']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['Feb 1, 2019 @ 00:05', '\t\t\t\t\t']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '\t\t\t\t\tMore news', '\t\t\t\t\t']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['Steel raw materials']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['Steel raw materials']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['Ferrous scrap']
# ['Iron ore']
# ['Coking coal']
# ['Ores and alloys']
# ['HBI, Pig iron & DRI']
# ['Alloy steel scrap']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '\tLatest news']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['China AM: Coking coal, coke futures rise further']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['Feb 1, 2019 @ 06:15', '\t\t\t\t\t']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['CIS PIG IRON: Market confused by opposing price trends in raw materials, HRC']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['Jan 31, 2019 @ 19:30', '\t\t\t\t\t']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['DAILY SCRAP REPORT: Prices inch down on more bookings ']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['Jan 31, 2019 @ 16:12', '\t\t\t\t\t']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '\t\t\t\t\tMore news', '\t\t\t\t\t']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['Semi finished products']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['Semi finished products']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['Billet']
# ['Slab']
# ['Bloom']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '\tLatest news']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['CIS STEEL BILLET: Market moves up after North African customers accept higher prices']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['Jan 31, 2019 @ 16:55', '\t\t\t\t\t']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['EGYPT STEEL BILLET, REBAR: Billet import prices rise, rebar prices to follow soon']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['Jan 31, 2019 @ 14:00', '\t\t\t\t\t']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['Iranian billet exporters push up prices after uptick in global market ']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['Jan 31, 2019 @ 11:06', '\t\t\t\t\t']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '\t\t\t\t\tMore news', '\t\t\t\t\t']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['Stainless & Special steels']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['Stainless & Special steels']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['Stainless flat products']
# ['Stainless long products']
# ['Special steels']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '\tLatest news']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ["China's crude stainless steel output hits new high in 2018"]
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['Feb 1, 2019 @ 05:40', '\t\t\t\t\t']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['European molybdenum markets extend gains']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['Jan 31, 2019 @ 15:30', '\t\t\t\t\t']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['US ferro-titanium major says no impact on output from fire']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['Jan 31, 2019 @ 12:25', '\t\t\t\t\t']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '\t\t\t\t\tMore news', '\t\t\t\t\t']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['Tube & pipe']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['Tube & pipe']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['Seamless']
# ['Welded']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '\tLatest news']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['EUROPE SECTIONS: Market stable ahead of import quota renewal']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['Jan 30, 2019 @ 17:23', '\t\t\t\t\t']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['EUROPE SECTIONS: Prices down after drop in HRC feedstock costs']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['Jan 23, 2019 @ 17:10', '\t\t\t\t\t']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['EUROPE SECTIONS: Prices unexpectedly fall after EU announces quota-tariff plan']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['Jan 16, 2019 @ 17:22', '\t\t\t\t\t']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '\t\t\t\t\tMore news', '\t\t\t\t\t']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['Supply chain & End users']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['Supply chain & End users']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['Supply chain']
# ['Traders']
# ['Stockists & Service Centres']
# ['Shipping & Logistics']
# ['Freight markets']
# ['', '']
# ['', '']
# ['End users']
# ['Construction']
# ['Auto & Transport']
# ['Consumer goods']
# ['Energy']
# ['Shipbuilding']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '\tLatest news']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['IN CASE YOU MISSED IT: 5 key stories from January 29']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['Jan 30, 2019 @ 00:05', '\t\t\t\t\t']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['IN CASE YOU MISSED IT: 5 key stories from January 22']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['Jan 23, 2019 @ 00:05', '\t\t\t\t\t']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '\t\t\t\t\tMore news', '\t\t\t\t\t']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['Industry']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['Industry']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['Statistics']
# ['Projects']
# ['Policy & Regulation']
# ['Corporate News']
# ['Environment']
# ['Mergers & Acquisitions']
# ['People']
# ['Trader talk']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '\tLatest news']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ["China's crude stainless steel output hits new high in 2018"]
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['Feb 1, 2019 @ 05:40', '\t\t\t\t\t']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['China’s Shagang raises long steel prices for early to mid-February']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['Feb 1, 2019 @ 03:28', '\t\t\t\t\t']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['China’s daily crude steel output drops in mid-January']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['Feb 1, 2019 @ 02:54', '\t\t\t\t\t']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['News']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['News']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['Latest news']
# ['', '']
# ['', '']
# ['', '']
# ['Daily briefs']
# ['', '']
# ['', '']
# ['', '']
# ['Weekly briefs']
# ['', '']
# ['', '']
# ['', '']
# ['Search Archive']
# ['', '']
# ['', '']
# ['', '']
# ['Columnists']
# ['', '']
# ['', '']
# ['', '']
# ['Hotline & Comment']
# ['', '']
# ['', '']
# ['', '']
# ['In Depth']
# ['', '']
# ['', '']
# ['', '']
# ['Daily & Magazine']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['Latest news']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '\tLatest news']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['China AM: Coking coal, coke futures rise further']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['Feb 1, 2019 @ 06:15', '\t\t\t\t\t']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ["China's crude stainless steel output hits new high in 2018"]
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['Feb 1, 2019 @ 05:40', '\t\t\t\t\t']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['LIVE FUTURES REPORT 01/02: SHFE base metals prices rangebound ahead of China’s week-long holiday']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['Feb 1, 2019 @ 04:30', '\t\t\t\t\t']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['China’s Shagang raises long steel prices for early to mid-February']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['Feb 1, 2019 @ 03:28', '\t\t\t\t\t']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '\t\t\t\t\tMore news', '\t\t\t\t\t']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['Daily briefs']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['Daily briefs']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['Daily PDF']
# ['Asian morning brief']
# ['European morning brief']
# ['North American morning brief']
# ['Daily futures rolling reports']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '\tLatest briefs']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['IN CASE YOU MISSED IT: 5 key stories from January 31']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['Feb 1, 2019 @ 00:05', '\t\t\t\t\t']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['IN CASE YOU MISSED IT: 5 key stories from January 30']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['Jan 31, 2019 @ 00:05', '\t\t\t\t\t']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['IN CASE YOU MISSED IT: 5 key stories from January 29']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['Jan 30, 2019 @ 00:05', '\t\t\t\t\t']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '\t\t\t\t\tMore news', '\t\t\t\t\t']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['Weekly briefs']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '\tLatest weekly briefs']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['NON-FERROUS WEEK IN BRIEF: Rio Tinto sells 40% stake in the Grasberg mine; Al market under pressure from Rusal sanctions relief; Antimony smugglers arrested in latest crackdown; Blockchain is coming']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['Dec 21, 2018 @ 17:29', '\t\t\t\t\t']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['STEEL WEEK IN BRIEF: High-grade 65% iron derivative launch by SGX, trade war truce, sanctions hitting Iran…']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['Dec 7, 2018 @ 20:01', '\t\t\t\t\t']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['NON-FERROUS WEEK IN BRIEF: Recylex addresses production woes at Weser Metall; Shanghai copper premiums fall to more than 1-yr low; Vale invests $500m in VNC nickel operation; Wealth Minerals plans copper project acquisition; cobalt monthly review ']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['Dec 7, 2018 @ 17:36', '\t\t\t\t\t']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ["NON-FERROUS WEEK IN BRIEF: MMG concludes sale of Sepon copper mine to Chifeng Jilong; Transnet declares force majeure on iron ore, manganese shipments from Saldanha; Chinese indium, bismuth, germanium markets 'recovering' in 2018"]
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['Nov 30, 2018 @ 18:24', '\t\t\t\t\t']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '\t\t\t\t\tMore news', '\t\t\t\t\t']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['Search Archive']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['Archive']
# ['', '']
# ['The\xa0Fastmarkets MB\xa0archives cover historical news and pricing data going back to 1997.']
# ['', '']
# ['View Archive']
# [' ']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['Columnists']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['Columnists']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['Hotter on Metals']
# ['Guest columnists']
# ['Lord Copper']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '\tLatest from columnists']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['DAVIES ON ORES: Some brighter spots for manganese after a dismal January ']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['Jan 30, 2019 @ 12:59', '\t\t\t\t\t']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['COMMENT: UK ferrous scrap demand to keep rising; particular upside for prime grades ']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['Jan 24, 2019 @ 12:35', '\t\t\t\t\t']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['HOTTER ON METALS: Aluminium’s Section 232 winners and losers ']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['Dec 20, 2018 @ 16:36', '\t\t\t\t\t']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['Hotline & Comment']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['Hotline & Comment']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['Comment']
# ['Hotline']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '\tLatest news']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['PEOPLE MOVES: MKM CEO Harings to take reins at Aurubis']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['Jan 30, 2019 @ 18:50', '\t\t\t\t\t']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['PEOPLE MOVES: Vital hires Nick Boulton as sales, product manager ']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['Jan 28, 2019 @ 16:21', '\t\t\t\t\t']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['PEOPLE MOVES: Copper concs trading head Olivier leaves MRI, sources say']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['Jan 25, 2019 @ 14:00', '\t\t\t\t\t']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '\t\t\t\t\tMore news', '\t\t\t\t\t']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['In Depth']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['In Depth']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['Interviews']
# ['Steel Market Outlook']
# ['Videos']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '\tLatest news']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['FOCUS: Zinc’s 2019 price prospects hinge on Chinese smelting bottleneck ']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['Jan 31, 2019 @ 11:20', '\t\t\t\t\t']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['FOCUS: Five questions about manganese ore positioning ']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['Jan 30, 2019 @ 15:29', '\t\t\t\t\t']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ["2019 PREVIEW: Asia's billet supply set to rise despite weak market, stiff competition"]
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['Jan 30, 2019 @ 08:37', '\t\t\t\t\t']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '\t\t\t\t\tMore news', '\t\t\t\t\t']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['Daily & Magazine']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '            Daily & Magazine', '        ']
# ['', '']
# ['Download the latest Daily for news from the last 24 hours plus all Fastmarkets MB prices, and the magazine for feature articles, market analysis and high-profile interviews.']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '                        Download']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['Download']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['Prices']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['Prices']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['Price Book']
# ['', '']
# ['', '']
# ['', '']
# ['Exchange news & prices']
# ['', '']
# ['', '']
# ['', '']
# ['My comparisons']
# ['', '']
# ['', '']
# ['', '']
# ['My prices']
# ['', '']
# ['', '']
# ['', '']
# ['Apex']
# ['', '']
# ['', '']
# ['', '']
# ['Pricing notices']
# ['', '']
# ['', '']
# ['', '']
# ['Price Guide & Methodology']
# ['', '']
# ['', '']
# ['', '']
# ['Data Price Feeds']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['Price Book']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['Price Book']
# ['', '']
# ["Track, chart, compare and export 950+ global metal, steel and scrap prices with Fastmarkets MB's pricing analysis tool."]
# ['', '']
# ['View Price Book']
# [' ']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['Exchange news & prices']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['Exchange news & prices']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['LME']
# ['NYMEX/COMEX']
# ['SHFE']
# ['Exchange news and prices price guide']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '\tLatest news']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['China AM: Coking coal, coke futures rise further']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['Feb 1, 2019 @ 06:15', '\t\t\t\t\t']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['LIVE FUTURES REPORT 01/02: SHFE base metals prices rangebound ahead of China’s week-long holiday']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['Feb 1, 2019 @ 04:30', '\t\t\t\t\t']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['LIVE FUTURES REPORT 31/01: LME base metals tick higher on positive trade sentiment; copper closes above $6,100']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['Jan 31, 2019 @ 18:58', '\t\t\t\t\t']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '\t\t\t\t\tMore news', '\t\t\t\t\t']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['My comparisons']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['My Comparisons']
# [' ']
# ['Find all your saved comparisons here. Compare up to five different prices over a selected period of time in Price Book.']
# [' ']
# [' ']
# ['View My comparisons']
# [' ']
# [' ']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['My prices']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['My Prices']
# ['Find all your bookmarked prices here. To bookmark a price click on the ‘Add to my saved prices’ icon in Price Book.']
# [' ']
# ['View My prices']
# [' ']
# [' ']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['Apex']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['Apex']
# [' ']
# ['MB Apex contains leader boards of analysts based upon the accuracy of their most recent price predictions.']
# [' ']
# [' ']
# ['View Apex']
# [' ']
# [' ']
# ['', '']
# ['', '']
# ['', '']
# ['/images/sites/846/navigation-images/prices/nav-apex.png was removed']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['Pricing notices']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['Pricing Notices']
# ['', '']
# ['Details of pricing methodology changes or price corrections.']
# ['', '']
# ['View Pricing notices ']
# ['', '']
# ['View Pricing Holidays ']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['Price Guide & Methodology']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['Price Guide & Methodology']
# ['', '']
# ["A complete list of all Fastmarkets MB's metal, steel and scrap prices, contained within our pricing analysis tool, Price Book."]
# ['', '']
# ['', '']
# ['View Methodology']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['Data Price Feeds']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['Data Price Feeds']
# ['', '']
# ["Get Fastmarkets MB's pricing data delivered directly to your spread sheet or integrated within your internal\xa0ERP/workflow."]
# ['', '']
# ['View Price Feeds']
# [' ']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['/images/sites/846/navigation-images/prices/nav-price-feeds.png was removed']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['Daily + Magazine']
# ['', '']
# ['', '']
# ['', '']
# ['Company Data']
# ['', '']
# ['', '']
# ['', '']
# ['Forecasts']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['Forecasts']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['Base metals']
# ['', '']
# ['', '']
# ['', '']
# ['Carbon steel']
# ['', '']
# ['', '']
# ['', '']
# ['Ores & alloys']
# ['', '']
# ['', '']
# ['', '']
# ['Steelmaking Raw materials']
# ['', '']
# ['', '']
# ['', '']
# ['Stainless & special steel']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['Base metals']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '\tLatest analysis']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['Bullish for base in 2018']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['Feb 28, 2018 @ 00:00', '\t\t\t\t\t']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['Carbon steel']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '\tLatest analysis']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['India’s Overwhelming Steel Projections?']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['Apr 15, 2018 @ 00:00', '\t\t\t\t\t']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['Steelmakers’ improvement continues but industry still under pressure']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['Mar 19, 2018 @ 00:00', '\t\t\t\t\t']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['Ilva and the Italian flat steel market – poised for a change?']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['Mar 12, 2018 @ 00:00', '\t\t\t\t\t']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['Modest changes in Chinese rebar demand spark acute price rises so can the reverse be true?']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['Mar 7, 2018 @ 00:00', '\t\t\t\t\t']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['Ores & alloys']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '\tLatest analysis']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['No stopping strong global EV sales growth ']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['Oct 2, 2018 @ 10:55', '\t\t\t\t\t']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['Steelmaking Raw materials']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '\tLatest analysis']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['Higher-grade iron ore prices pioneered the downtrend in the Chinese steelmaking raw material market in November']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['Nov 28, 2018 @ 00:00', '\t\t\t\t\t']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['BIR LONDON: US scrap market still depends on Turkey after Section 232']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['Nov 5, 2018 @ 00:00', '\t\t\t\t\t']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['Is there room for China to import MPI once again?']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['Jun 21, 2018 @ 00:00', '\t\t\t\t\t']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['Is China’s lean toward scrap sustainable?']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['Feb 19, 2018 @ 00:00', '\t\t\t\t\t']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['Stainless & special steel']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '\tLatest analysis']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '', '  if (!window.MB) {', '    window.MB = {};', '  }', '  ', '  if (!window.search) {', '    window.search = {};', '  }', '  ', "  window.search.searchApiUrl = 'https://search.euromoneyapi.com';", "  window.search.subscription = 'NotLoggedIn';", '  ', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '\t\t\tFree Trial ']
# ['', '']
# ['', '']
# ['', '\t\t\tSubscribe ']
# ['', '']
# ['', '']
# ['', '\t\t\tLog in ']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '', '  if (!window.MB) {', '    window.MB = {};', '  }', '  ', '  if (!window.search) {', '    window.search = {};', '  }', '  ', "  window.search.searchApiUrl = 'https://search.euromoneyapi.com';", "  window.search.subscription = 'NotLoggedIn';", '  ', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['Home']
# ['', '']
# ['', '']
# ['Search results']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['Search results for ']
# ['{{didYouMeanCorrected ? didYouMeanCorrected : \'"\'+queryTerm+\'"\' }}']
# ['', '']
# ['', '']
# ['', '']
# ['Search results for ']
# ['"{{ queryTerm }}"']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['News']
# ['', '']
# ['', '']
# ['', '']
# ['Prices']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# [' Tab panes ']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# [' article list ']
# ['', '']
# ['', '']
# [' sorting ']
# ['', '']
# ['', '']
# ['', '']
# [' sorting ']
# ['', '']
# ['{{errorMessage}}']
# ['', '']
# ['', '']
# ['No results for: {{didYouMeanOriginal}}']
# ['', '']
# ['Showing results for ']
# ['{{didYouMeanCorrected}}']
# ['.']
# ['', '']
# ['Search instead for: ']
# ['{{didYouMeanOriginal}}']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['Sort by:', '\t\t\t\t\t\t\t\t']
# ['', '']
# ['|']
# ['', '']
# ['', '']
# ['{{sortOption}}']
# ['', '']
# ['', '']
# ['{{sortOption}}']
# ['', '']
# ['', '']
# ['', '']
# ["Found {{resultsCount()}} results {{queryTerm ? 'for' : ''}} "]
# ['{{didYouMeanCorrected ? didYouMeanCorrected : queryTerm}}']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['No results found for "']
# ['{{didYouMeanCorrected ? didYouMeanCorrected : queryTerm}}']
# ['".']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ["{{article|snippet:'title'|removeHtmlTags}}"]
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ["{{article|fields:'dates'|date:dateArticleFormat}}"]
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ["{{article|fields:'authors'}}"]
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['{{pg.value}}']
# ['', '']
# ["{{pg.value == 'Next'?'»' : pg.value == 'Previous' ? '«' : pg.value}}"]
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['  price results  ']
# ['', '']
# ['', '']
# [' sorting ']
# ['', '']
# ['', '']
# ['', '']
# [' sorting ']
# ['', '']
# ['{{errorMessage}}']
# ['', '']
# ['', '']
# ['No results for: {{didYouMeanOriginal}}']
# ['', '']
# ['Showing results for ']
# ['{{didYouMeanCorrected}}']
# ['.']
# ['', '']
# ['Search instead for: ']
# ['{{didYouMeanOriginal}}']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['Sort by:', '\t\t\t\t\t\t\t\t']
# ['', '']
# ['|']
# ['', '']
# ['', '']
# ['{{sortOption}}']
# ['', '']
# ['', '']
# ['{{sortOption}}']
# ['', '']
# ['', '']
# ['', '']
# ["Found {{resultsCount()}} results {{queryTerm ? 'for' : ''}} "]
# ['{{didYouMeanCorrected ? didYouMeanCorrected : queryTerm}}']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['The current pricing data is only available to subscribers, please\xa0']
# ['login']
# ['\xa0to see the data or ']
# ['take a trial']
# ['.']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['No results found for "']
# ['{{didYouMeanCorrected ? didYouMeanCorrected : queryTerm}}']
# ['".']
# ['', '']
# ['', '']
# ['', '\t\t\t\t\t\tPlease try different search terms or broaden your search criteria.']
# ['If you think there is something missing here, ']
# ['please let us know']
# ['.\r', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['Price description']
# ['', '']
# ['Date']
# ['', '']
# ['Price']
# ['', '']
# ['Actions']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['{{price.Title|removeHtmlTags}}']
# ['', '']
# ['{{price.Date}}']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['Saved']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['{{pg.value}}']
# ['', '']
# ["{{pg.value == 'Next'?'»' : pg.value == 'Previous' ? '«' : pg.value}}"]
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '', '      if (!window.searchResultsInfo) {', '        window.searchResultsInfo = {};', '      }', '', '      window.searchResultsInfo.loginStatus = "not logged in";', '      window.searchResultsInfo.customerId = "0";', '      window.searchResultsInfo.subscriber_id = "0";', '', '    ']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '      Show filters', '      ']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '      Hide filters', '      ']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '', "angular.module('searchApp').constant('MyPublications', {});", '', "\tangular.module('searchApp')", "\t\t.filter('formatDate', function() {", '\t\t\treturn function(input) {', "\t\t\t\treturn input.toString().replace(/-/g, '/');", '\t\t\t};', '\t\t});', '', '$(function() {', "\t\tvar scope = $('#searchFacetsElement').scope();", '', '\t\t// toggleOptionEx', '\t\t//', '\t\tscope.toggleOptionEx = function(facet, term) {', '\t\t\t// reset period date filters', '\t\t\tscope.toggleDateValue(true);', '\t\t\t// reset predefined date filter', '\t\t\tif (scope.facets) {', '\t\t\t\t$.each(scope.facets, function (index, facet1) {', "\t\t\t\t\tif (facet1.name=='dates' && scope.hasSelectedOptions(facet1)) {", '\t\t\t\t\t\t$.each(facet1.options, function (index2, option) {', '\t\t\t\t\t\t\tif (option.isSelected && option.term !== term) {', '\t\t\t\t\t\t\t\tscope.toggleOption(facet1, option.term);', '\t\t\t\t\t\t\t}', '\t\t\t\t\t\t});', '\t\t\t\t\t}', '\t\t\t\t});', '\t\t\t}', '', '\t\t\t// set new filter', '\t\t\tscope.toggleOption(facet, term);', '\t\t}', '', '\t\t// anySelectedOptions', '\t\t//', '\t\tscope.anySelectedOptions = function (facets) {', "\t\t\tvar scope = $('#searchFacetsElement').scope();", '\t\t\tfor (var i = 0, l = facets.length; i < l; i++) {', '\t\t\t\tif (scope.hasSelectedOptions(facets[i])) {', '\t\t\t\t\treturn true;', '\t\t\t\t}', '\t\t\t}', '', '\t\t\treturn false;', '\t\t}', '', '\t});', '', '']
# ['', '']
# ['', '']
# ['Filter results by:']
# ['', '']
# ['', '']
# ['', '\t\t\tCurrent filters']
# ['Reset All']
# ['', '']
# ['', '']
# ['', '']
# ['{{facet.name|displayName}}']
# ['', '']
# ['', '']
# ['{{option.term}}', '\t\t\t\t\t']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['{{facets[0].period.dateFrom|formatDate}} - {{facets[0].period.dateTo|formatDate}}', '\t\t\t\t\t']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '\t\t$("#hide-filters").click(function() {', '\t\t\t$("#applied-filters").fadeOut("slow", function() {', '\t\t\t});', '\t\t});', '', '\t\tfunction toShortDate(date) {', "\t\t\treturn moment(date).format('DD-MM-YY');", '\t\t}', '', '\t\tfunction DatePickerCB(start, end, label) {', "\t\t\tif (label != 'Cancel') {", "\t\t\t\tvar datePanelScope = angular.element($('#datePanel')).scope();", '', '\t\t\t\tdatePanelScope.facet.period.dateFrom = toShortDate(start);', '\t\t\t\tdatePanelScope.facet.period.dateTo = toShortDate(end);', '\t\t\t\tdatePanelScope.toggleDateValue(false);', '\t\t\t\tdatePanelScope.$apply();', '\t\t\t}', '\t\t}', '\t']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['{{facet.name|displayName}}', '\t\t\t\t\t\t\t\t\t\t']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['{{option.term}}']
# ['', '']
# ['{{option.count}}']
# ['', '']
# ['', '']
# ['Specific range ']
# ['(DD/MM/YYYY)']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['{{facet.name|displayName}}', '\t\t\t\t\t\t\t\t\t']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['{{option.term}}']
# ['', '']
# ['{{option.count}}']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['Refine results:']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '\t\t\t\t\t\t\t\tSearch by name', '\t\t\t\t\t\t\t\t']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['Search only current prices']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '\t\t\t\t\t\tALL MATERIAL SUBJECT TO STRICTLY ENFORCED COPYRIGHT LAWS.© EUROMONEY GLOBAL LIMITED', '\t\t\t\t\t']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['Categories']
# ['', '']
# ['', '']
# ['', '']
# ['Prices']
# ['', '']
# ['', '']
# ['', '']
# ['Metals']
# ['', '']
# ['', '']
# ['', '']
# ['News']
# ['', '']
# ['', '']
# ['', '']
# ['Company Data']
# ['', '']
# ['', '']
# ['', '']
# ['Data Solutions']
# ['', '']
# ['', '']
# ['', '']
# ['Data Feeds']
# ['', '']
# ['', '']
# ['', '']
# ['Third Party Platforms']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['Support']
# ['', '']
# ['', '']
# ['', '']
# ['Contact us']
# ['', '']
# ['', '']
# ['', '']
# ['About us']
# ['', '']
# ['', '']
# ['', '']
# ['FAQs']
# ['', '']
# ['', '']
# ['', '']
# ['Advertising']
# ['', '']
# ['', '']
# ['', '']
# ['Glossary']
# ['', '']
# ['', '']
# ['', '']
# ['Site map']
# ['', '']
# ['', '']
# ['', '']
# ['Fastmarkets MB App']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['My Fastmarkets MB']
# ['', '']
# ['', '']
# ['', '']
# ['Price Book']
# ['', '']
# ['', '']
# ['', '']
# ['My Prices']
# ['', '']
# ['', '']
# ['', '']
# ['Saved comparisons']
# ['', '']
# ['', '']
# ['', '']
# ['Products']
# ['', '']
# ['', '']
# ['', '']
# ['Data Licensing']
# ['', '']
# ['', '']
# ['', '']
# ['Webinars']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '\t\tFollow Fastmarkets MB', '\t']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['Follow us on Twitter']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['Join our LinkedIn group']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['View our YouTube channel']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['Terms & conditions']
# ['', '']
# ['Copyright Notice']
# ['', '']
# ['Privacy policy']
# ['', '']
# ['Cookies']
# ['', '']
# ['Disclaimer']
# ['', '']
# ['Advertising']
# ['', '']
# ['Modern Slavery Act Transparency Statement']
# ['', '']
# ['', '']
# ['Copyright ©Euromoney Global Limited. All rights reserved.']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# [' NEWSLETTER MODAL ']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['Thank you for subscribing!']
# ['', '']
# ['', '']
# ['', '']
# ['By signing up to this free newsletter you agree to receive occasional emails from us informing you about our products and services. You can opt out of these emails at any time.']
# ['', '']
# ['', '']
# ['Terms & conditions']
# ['', '']
# ['Privacy policy']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['Close']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['Corporate account successfully created.']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ["You're now logged in."]
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['Ok']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '\t\t\tvar isPageValidFunction = typeof Page_ClientValidate === "function";', '\t\t\tif (!isPageValidFunction) {', '\t\t\t\tPage_ClientValidate = function () { };', '\t\t\t}', '\t\t']
# ['', '']
# ["var CookieAccepterCssClasses = { grayBody: 'cookieAccepterGrayBody',popupPanel: 'cookieAccepterPopup',popupButton: 'cookieAccepterPopupButton',popupCloseButton: 'cookieAccepterPopupCloseButton',slideButton: 'cookieAccepterSliderButton',slideLink: 'cookieAccepterSliderLink',slidePanel: 'cookieAccepterSlider'};InitCookieAccepterEffect(CookieAccepterCssClasses);"]
# ['\r', '$(document).ready(function(){\r', "$('body').css('overflow', 'auto');\r", '})\r', '']
# ['', '']
# ['\r', '//<![CDATA[\r', '(function (window, $) {', '', '    window.euromoney = window.euromoney || {};', '\twindow.euromoney.dataLayer = window.euromoney.dataLayer || {};', '', '\tfunction googleAnalyticsCommon() {', '', '        var module = {}', '', '        var pushToDataLayer = function (json) {', '            if (typeof json != "string") {', '                json = JSON.stringify(json);', '            }', '', '            json = JSON.parse(json);', '', '            window.dataLayer = window.dataLayer || [];', '            window.dataLayer.push(json);', '        }', '', '        var ready = function(targetFunction) {', '            if(window.euromoney.dataLayer.isGaEnabled) {', '                jQuery(document).ready(targetFunction);', '            }', '        }', '', '        module.pushToDataLayer = pushToDataLayer;', '        module.ready = ready;', '', '        return module;', '    }', '', '    window.euromoney.googleAnalyticsCommon = googleAnalyticsCommon();', '})(window, jQuery);(function (window, $) {', '', '    window.euromoney = window.euromoney || {};', '    window.euromoney.dataLayer = window.euromoney.dataLayer || {};', '', '    function googleAnalyticsWebForms() {', '', '        var module = {}', '', '        var ready = function (targetFunction) {', '            if (window.euromoney.dataLayer.isGaEnabled) {', '                try {', '                    Sys.Application.add_init(targetFunction);', '                } catch (e) {', '                    jQuery(document).ready(targetFunction);', '                }', '            }', '        };', '', '        if (typeof (Page_ClientValidate) === "function") {', '            module.Page_ClientValidate = Page_ClientValidate;', '        } else {', '            module.Page_ClientValidate = function (validationGroup) { return true; };', '        }', '        module.isInitialized = false;', '        module.ready = ready;', '', '        return module;', '    }', '', '    window.euromoney.googleAnalyticsWebForms = googleAnalyticsWebForms();', '})(window, jQuery);(function (window, $) {', '', '    window.euromoney = window.euromoney || {};', '\twindow.euromoney.dataLayer = window.euromoney.dataLayer || {};', '', '\tfunction googleAnalytics() {', '', '        var module = {}', '', '        var logInteraction = function (element, interactionObject) {', '            interactionObject = interactionObject || element.data("gaInteractionObject") || {};', '            module.pushToDataLayer(interactionObject);', '        }', '', '        var prepareInteractionEvent = function (element, eventType, interactionObject) {', '            element = $(element);', '            eventType = eventType || element.data("gaInteractionEvent");', '', '            var isTimeoutEvent = element.data("gaInteractionTimeout") !== undefined;', '            var isScrollEvent = element.data("gaInteractionScroll") != undefined;', '            if (isTimeoutEvent) {', '                setTimeout(function () { logInteraction(element, interactionObject); },', '                    euromoney.dataLayer.timeout);', '            } else if (isScrollEvent) {', '                logUserReachedEndOfElement(element, interactionObject);', '            } else if (eventType !== undefined) {', '                element.on(eventType,', '                    function () {', '                        logInteraction(element, interactionObject);', '                    });', '            }', '        }', '', '        var initializeFormField = function (index, element, interactionObject) {', '            element = $(element);', '', '\t        if (interactionObject == undefined) {', '\t\t        var originalInteractionObject = element.closest(".em-trackedForm").data("gaInteractionObject");', '\t\t        interactionObject = JSON.parse(JSON.stringify(originalInteractionObject));', '\t        }', '', '\t        interactionObject.interaction_name = "form tracking";', '            interactionObject.form_track_field = element.data("gaFiel ...
# ['', '']
# ['', '']
# ['', '']
# ['', '//<![CDATA[', '(function() {', "var _analytics_scr = document.createElement('script');", "_analytics_scr.type = 'text/javascript'; _analytics_scr.async = true; _analytics_scr.src = '/_Incapsula_Resource?SWJIYLWA=719d34d31c8e3a6e6fffd425f7e032f3&ns=2&cb=1461745393';", "var _analytics_elem = document.getElementsByTagName('script')[0]; _analytics_elem.parentNode.insertBefore(_analytics_scr, _analytics_elem);", '})();', '// ]]>', '']
# ['', '']
# ['', '']

# %%
data = 
for div in data:
    li=soup1.findAll('p')

# %%
for hit in soup1.find('div'):
    #for elem in hit.findAll('span'):
    print(hit)
#         for el in elem.findAll('p'):
#             print(el)

# %%
for hit in soup1.findAll('div',attrs={'class':'headline'}):
    print(hit)
# Out:
# <div class="headline">
# <div class="headline-title">
# <a href="/Article/3856428/base-metals/LIVE-FUTURES-REPORT-3101-SHFE-base-metals-prices-broadly-push-up-on-weak-US-dollar-easing-trade.html" onclick='GoogleTagManagerLogger.LogCustomAction("navigation click", "nav_link_type:latest news","nav_link_name:LIVE FUTURES REPORT 3101 SHFE base metals prices broadly push up on weak US dollar easing trade tensions");'><img alt="image" class="img-responsive" id="topMenu_rptMenu_rptThirdLevelPanels_0_ctl02_0_ctl02_0_rptArticles_0_imgImage_0" src="https://cdn.metalbulletin.com/images/656/99930/Live_Futures_LME_price_report_(SS)_465x310.jpg"/>LIVE FUTURES REPORT 31/01: SHFE base metals prices broadly push up on weak US dollar, easing trade tensions</a>
# </div>
# <div class="headline-meta">
# <div class="headline-time">
# <span class="far fa-clock"></span>Jan
00
# 					</div>
# </div>
# </div>
# <div class="headline">
# <div class="headline-title">
# <a href="/Article/3792472/Scrap-and-secondary/Modest-changes-in-Chinese-rebar-demand-spark-acute-price-rises-so-can-the-reverse-be-true.html" onclick='GoogleTagManagerLogger.LogCustomAction("navigation click", "nav_link_type:latest news","nav_link_name:Modest changes in Chinese rebar demand spark acute price rises so can the reverse be true?");'><img alt="image" class="img-responsive" id="topMenu_rptMenu_rptThirdLevelPanels_6_ctl02_1_ctl02_1_rptArticles_1_imgImage_3" src="https://cdn.metalbulletin.com/images/656/95773/Rebar%20bundles%20465x310.jpg"/>Modest changes in Chinese rebar demand spark acute price rises so can the reverse be true?</a>
# </div>
# <div class="headline-meta">
# <div class="headline-time">
# <span class="far fa-clock"></span>Mar 7, 2018 @ 00:00
# 					</div>
# </div>
# </div>
# <div class="headline">
# <div class="headline-title">
# <a href="/Article/3835141/Scrap-and-secondary/No-stopping-strong-global-EV-sales-growth.html" onclick='GoogleTagManagerLogger.LogCustomAction("navigation click", "nav_link_type:latest news","nav_link_name:No stopping strong global EV sales growth ");'><img alt="image" class="img-responsive" id="topMenu_rptMenu_rptThirdLevelPanels_6_ctl02_2_ctl02_2_rptArticles_2_imgImage_0" src="https://cdn.metalbulletin.com/images/656/99598/Tesla%20Model%203%20465x310.jpg"/>No stopping strong global EV sales growth </a>
# </div>
# <div class="headline-meta">
# <div class="headline-time">
# <span class="far fa-clock"></span>Oct 2, 2018 @ 10:55
# 					</div>
# </div>
# </div>
# <div class="headline">
# <div class="headline-title">
# <a href="/Article/3846532/Scrap-and-secondary/Higher-grade-iron-ore-prices-pioneered-the-downtrend-in-the-Chinese-steelmaking-raw-material-market.html" onclick='GoogleTagManagerLogger.LogCustomAction("navigation click", "nav_link_type:latest news","nav_link_name:Higher-grade iron ore prices pioneered the downtrend in the Chinese steelmaking raw material market in November");'><img alt="image" class="img-responsive" id="topMenu_rptMenu_rptThirdLevelPanels_6_ctl02_3_ctl02_3_rptArticles_3_imgImage_0" src="https://cdn.metalbulletin.com/images/656/95773/Iron%20Ore%20Port%20Hedland%20Credit%20BHPBilliton%20465x310.jpg"/>Higher-grade iron ore prices pioneered the downtrend in the Chinese steelmaking raw material market in November</a>
# </div>
# <div class="headline-meta">
# <div class="headline-time">
# <span class="far fa-clock"></span>Nov 28, 2018 @ 00:00
# 					</div>
# </div>
# </div>
# <div class="headline">
# <div class="headline-title">
# <a href="/Article/3842357/Scrap-and-secondary/BIR-LONDON-US-scrap-market-still-depends-on-Turkey-after-Section-232.html" onclick='GoogleTagManagerLogger.LogCustomAction("navigation click", "nav_link_type:latest news","nav_link_name:BIR LONDON US scrap market still depends on Turkey after Section 232");'><img alt="image" class="img-responsive" id="topMenu_rptMenu_rptThirdLevelPanels_6_ctl02_3_ctl02_3_rptArticles_3_imgImage_1" src="https://cdn.metalbulletin.com/images/656/95773/Grabbing%20ferrous%20scrap%20465x310.jpg"/>BIR LONDON: US scrap market still depends on Turkey after Section 232</a>
# </div>
# <div class="headline-meta">
# <div class="headline-time">
# <span class="far fa-clock"></span>Nov 5, 2018 @ 00:00
# 					</div>
# </div>
# </div>
# <div class="headline">
# <div class="headline-title">
# <a href="/Article/3815214/Scrap-and-secondary/Is-there-room-for-China-to-import-MPI-once-again.html" onclick='GoogleTagManagerLogger.LogCustomAction("navigation click", "nav_link_type:latest news","nav_link_name:Is there room for China to import MPI once again?");'><img alt="image" class="img-responsive" id="topMenu_rptMenu_rptThirdLevelPanels_6_ctl02_3_ctl02_3_rptArticles_3_imgImage_2" src="https://cdn.metalbulletin.com/images/656/95773/Stacked%20ferrous%20scrap%20bales%20465x310.jpg"/>Is there room for China to import MPI once again?</a>
# </div>
# <div class="headline-meta">
# <div class="headline-time">
# <span class="far fa-clock"></span>Jun 21, 2018 @ 00:00
# 					</div>
# </div>
# </div>
# <div class="headline">
# <div class="headline-title">
# <a href="/Article/3788395/Scrap-and-secondary/Is-Chinas-lean-toward-scrap-sustainable.html" onclick='GoogleTagManagerLogger.LogCustomAction("navigation click", "nav_link_type:latest news","nav_link_name:Is Chinas lean toward scrap sustainable?");'><img alt="image" class="img-responsive" id="topMenu_rptMenu_rptThirdLevelPanels_6_ctl02_3_ctl02_3_rptArticles_3_imgImage_3" src="https://cdn.metalbulletin.com/images/656/95773/shredded_steel-465x310.gif"/>Is China’s lean toward scrap sustainable?</a>
# </div>
# <div class="headline-meta">
# <div class="headline-time">
# <span class="far fa-clock"></span>Feb 19, 2018 @ 00:00
# 					</div>
# </div>
# </div>
# <div class="headline">
# <h4 ng-class="headline-title|publicationClass">
# <a ng-click="LogSearchSelect('search select result', 'search_select_index:' + ($index + 1))" ng-href="{{article|articleHrefWithBreadcrumb}}">{{article|snippet:'title'|removeHtmlTags}}</a>
# </h4>
# <span class="headline-intro" ng-bind-html="article|resultContent"></span>
# <span class="headline-meta">
# <span class="headline-time">
# <span class="far fa-clock"></span>
# <span>{{article|fields:'dates'|date:dateArticleFormat}}</span>
# </span>
# <span class="headline-user">
# <span class="fa fa-user padding-left-single" ng-if="article.fields.authors.length &gt; 0"></span>
# <span ng-if="article.fields.authors.length &gt; 0">{{article|fields:'authors'}}</span>
# </span>
# </span>
# </div>

# %%
soup1.findAll('p',attrs={'class':'headline'})
# Out:
# []

# %%
elem=pd.DataFrame(elem)

# %%
elem
# Out:
#                                                     0
# 0   /Article/3856211/base-metals/LIVE-FUTURES-REPO...
# 1   /Article/3856191/base-metals/GLOBAL-COPPER-WRA...
# 2   /Article/3856171/base-metals/METALS-MORNING-VI...
# 3   /Article/3855644/Ores-and-alloys/BATTERY-RAW-M...
# 4   /Article/3854597/Ores-and-alloys/BATTERY-RAW-M...
# 5   /Article/3856036/Raw-materials/GLOBAL-CHROME-W...
# 6   /Article/3856025/Raw-materials/GLOBAL-MANGANES...
# 7   /Article/3855794/Raw-materials/Zinc-concentrat...
# 8   /Article/3855404/Minor-metals/2019-PREVIEW-Thr...
# 9   /Article/3856017/Minor-metals/Fanya-indium-auc...
# 10  /Article/3856191/Scrap-and-secondary/GLOBAL-CO...
# 11  /Article/3855982/Scrap-and-secondary/2019-PREV...
# 12  /Article/3856079/Scrap-and-secondary/DAILY-SCR...
# 13  /Article/3856171/Precious-metals/METALS-MORNIN...
# 14  /Article/3856115/Precious-metals/INTERVIEW-Pos...
# 15  /Article/3856077/Precious-metals/LIVE-FUTURES-...
# 16  /Article/3856139/battery-raw-materials/COMMENT...
# 17  /Article/3856081/battery-raw-materials/PRICING...
# 18  /Article/3852093/battery-raw-materials/Trade-l...
# 19  /Article/3856173/flat-products/CHINA-HRC-Price...
# 20  /Article/3856161/flat-products/China-AM-Iron-o...
# 21  /Article/3856071/flat-products/RUSSIA-FLAT-STE...
# 22  /Article/3856170/long-products/CHINA-REBAR-Pri...
# 23  /Article/3856155/long-products/Long-Steel-Prod...
# 24  /Article/3856161/long-products/China-AM-Iron-o...
# 25  /Article/3856173/steel-raw-materials/CHINA-HRC...
# 26  /Article/3856164/steel-raw-materials/Iron-ore-...
# 27  /Article/3855982/steel-raw-materials/2019-PREV...
# 28  /Article/3856170/Semi-finished-products/CHINA-...
# 29  /Article/3855982/Semi-finished-products/2019-P...
# ..                                                ...
# 45  /Article/3856197/Latest-news/COKING-COAL-DAILY...
# 46  /Article/3856135/Daily-briefs/IN-CASE-YOU-MISS...
# 47  /Article/3855967/Daily-briefs/IN-CASE-YOU-MISS...
# 48  /Article/3855715/Daily-briefs/IN-CASE-YOU-MISS...
# 49  /Article/3850953/Weekly-briefs/NON-FERROUS-WEE...
# 50  /Article/3848301/Weekly-briefs/STEEL-WEEK-IN-B...
# 51  /Article/3848298/Weekly-briefs/NON-FERROUS-WEE...
# 52  /Article/3847184/Weekly-briefs/NON-FERROUS-WEE...
# 53  /Article/3855332/Scrap-and-secondary/COMMENT-U...
# 54  /Article/3850445/Scrap-and-secondary/HOTTER-ON...
# 55  /Article/3849028/Scrap-and-secondary/HOTTER-ON...
# 56  /Article/3855933/Hotline-and-Comment/PEOPLE-MO...
# 57  /Article/3855529/Hotline-and-Comment/PEOPLE-MO...
# 58  /Article/3855355/Hotline-and-Comment/PEOPLE-MO...
# 59  /Article/3855982/in-depth/2019-PREVIEW-Asias-b...
# 60  /Article/3855404/in-depth/2019-PREVIEW-Three-t...
# 61  /Article/3856121/in-depth/FORECAST-Market-expe...
# 62  /Article/3856211/Exchange-news-and-prices/LIVE...
# 63  /Article/3856173/Exchange-news-and-prices/CHIN...
# 64  /Article/3856197/Exchange-news-and-prices/COKI...
# 65  /Article/3790690/Scrap-and-secondary/Bullish-f...
# 66  /Article/3800977/Scrap-and-secondary/Indias-Ov...
# 67  /Article/3794840/Scrap-and-secondary/Steelmake...
# 68  /Article/3793304/Scrap-and-secondary/Ilva-and-...
# 69  /Article/3792472/Scrap-and-secondary/Modest-ch...
# 70  /Article/3835141/Scrap-and-secondary/No-stoppi...
# 71  /Article/3846532/Scrap-and-secondary/Higher-gr...
# 72  /Article/3842357/Scrap-and-secondary/BIR-LONDO...
# 73  /Article/3815214/Scrap-and-secondary/Is-there-...
# 74  /Article/3788395/Scrap-and-secondary/Is-Chinas...
#
# [75 rows x 1 columns]

# %%
<span class="headline-intro ng-binding"

# %%
r=soup1.findAll('div',attrs={'class':"headline"})[0]
p=r.find('a')
p.get('href')

# %%
r.findAll('span',attrs={'class':'headline-intro ng-binding'})

# %%
r.find_all('span')

# %%
soup1.findAll('span',)

# %%
soup1.find('div', attrs={'class':'headline-intro ng-binding'})

# %%
html.findAll('p')

# %%
soup1.find_all('span',class_="headline-intro ng-binding")

# %%
soup1.findAll('ng-class')

# %%
for links in soup1.find_all('div','headline'):
    for link in soup1.find_all('p'):
        print(link)

# %%
hi=soup1.select()
hi

# %%
soup1.select('.job turnstileLink')

# %%
hi[0].getText()

# %%
res1=requests.get("https://en.wikipedia.org/wiki/Machine_learning")

# %%
type(res1)

# %%
soup=bs4.BeautifulSoup(res1.text,'lxml')

# %%
soup.select('.mw-headline')

# %%
for i in soup.select('.mw-headline'):
    print(i.text)

# %%
soup.select('.toctext')

# %%
for i in soup.select('.toctext'):
    print(i.text)

# %%
for i in soup.select('#toc'):
        print(i.text)

# %%
for link in soup1.findAll('a',href=True):
    if link['href'].startswith(('#','/','j')):
        print("")
    else:
        print(link['href'])

# %%
print(soup.get_text())

# %%
head_tag = soup.head
#head_tag
# <head><title>The Dormouse's story</title></head>

# head_tag.contents
# [<title>The Dormouse's story</title>]

title_tag = head_tag.contents[0]
# title_tag
# # <title>The Dormouse's story</title>
# title_tag.contents
# # [u'The Dormouse's story']

# %%
title_tag.contents

# %%
res2=requests.get('https://www.indeed.co.in/jobs?q=&l=Jaipur%2C+Rajasthan')

# %%
soup2=bs4.BeautifulSoup(res2.content,'html.parser')

# %%
jobT = soup2.findAll('a', {'class':'jobtitle turnstileLink' })
for el in jobT:
    print(el.get('title'))

# %%
# for cl in soup2.findAll('div'):
#     print(cl[0])
t=soup2.findAll('div',class_='jobtitle turnstileLink')
t
