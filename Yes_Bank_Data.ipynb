# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_excel('data_for_powerBI.xlsx')

# %%
data.head()
# Out:
#                  time      value  cpuused  RAM  Network  Disk
# 0 2019-01-05 00:00:00  29.333333     24.4   43       27    18
# 1 2019-01-05 00:10:00  44.000000      7.5   27       62    43
# 2 2019-01-05 00:20:00  28.666667      3.1   18       51    17
# 3 2019-01-05 00:30:00  50.000000      2.6   61       26    63
# 4 2019-01-05 00:40:00  44.000000      2.9   61       42    29

# %%
data['date']=data['time'].dt.date

# %%
data.dtypes
# Out:
# time       datetime64[ns]
# value             float64
# cpuused           float64
# RAM                 int64
# Network             int64
# Disk                int64
# date               object
# dtype: object

# %%
data.head()
# Out:
#                  time      value  cpuused  RAM  Network  Disk        date
# 0 2019-01-05 00:00:00  29.333333     24.4   43       27    18  2019-01-05
# 1 2019-01-05 00:10:00  44.000000      7.5   27       62    43  2019-01-05
# 2 2019-01-05 00:20:00  28.666667      3.1   18       51    17  2019-01-05
# 3 2019-01-05 00:30:00  50.000000      2.6   61       26    63  2019-01-05
# 4 2019-01-05 00:40:00  44.000000      2.9   61       42    29  2019-01-05

# %%
data['day']=data['time'].apply(lambda x: x.day)

# %%
data.loc[data['day']==5,'Flag']='Actual'

# %%
data.loc[data['day']==6,'Flag']='Predicted'

# %%
del data['day']

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(data['value'])

# %%
import statsmodels.api as sm
y=data['value']

# %%
y.shape
# Out:
# (288,)

# %%
y=np.random.uniform(-2, 2, (288))
plt.plot(y)

# %%
import matplotlib.pyplot as plt 
import numpy as np 
  
# setting the x - coordinates 
x = np.random.uniform(-2, 2, (288))
# setting the corresponding y - coordinates 
y = np.sin(x) 
  
# potting the points 
plt.plot(x,y) 
  
# function to show the plot 
plt.show()

# %%
z=np.linspace(-np.pi, np.pi, 201)

# %%
def f(t):
    return np.exp(-t) * np.cos(2*np.pi*t)

t1 = np.random.uniform(-2, 2, (144))
t2 =np.random.uniform(-2, 2, (144))

plt.figure(1)
plt.subplot(211)
plt.plot(x, f(x), 'bo', t2, f(t2), 'k')

# %%
x = np.linspace(0.0, 5.0, 144)
y= np.cos(2*np.pi*x) * np.exp(-x)

# %%
plt.plot(y)

# %%
x = np.linspace(-2, 5, 144)
y= np.sin(2*np.pi*x) * np.exp(-(x))
z= np.cos(2*np.pi*x) * np.exp((x))

# %%
plt.plot(y)

# %%
plt.plot(z)

# %%
plt.plot(y[:70])

# %%
plt.plot(z)

# %%
import matplotlib.pyplot as pl
import numpy as np

x = np.linspace(-2, 2,144)

def f(x):
    return np.sin(x) + np.random.normal(scale=0.1, size=len(x))

pl.plot(x, f(x))

# %%
def f(x):
    y = 0
    result = []
    for _ in x:
        result.append(y)
        y += np.random.normal(scale=1)
    return np.array(result)
C=f(x)
plt.plot(C)

# %%
C=C*10
C
# Out:
# array([   0.        ,  127.26060985,   12.74014539,   74.42932999,
#         147.29382062,  272.35358998,  348.73512095,  375.08689598,
        41.92997707,  52.03170068,  54.02181961,  60.98451394,
        65.38630756,  61.779217  ,  62.03979536,  64.61244092,
        62.79514241,  64.42731924,  69.9944597 ,  74.57180035,
        91.73225704, 111.85759603, 109.42817294, 121.56262346,
       132.24344879, 135.18731763, 130.61097644, 157.27504584]

# %%
u=u*10
plt.plot(u)
plt.title('Actual')
# Out:
# Text(0.5,1,'Actual')

# %%
X=u

# %%
data['value'][:144]=X
# Out:
# /home/ayushi/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
data['value'][144:]=C
# Out:
# /home/ayushi/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
plt.plot(C[:80])

# %%
plt.plot(X)

# %%
plt.plot(X[135:144])

# %%
S=X

# %%
plt.plot(S)

# %%
S[135:144]=Y
plt.plot(S)

# %%
X[80:120]
# Out:
# array([ 74.27374628,  84.45694644,  86.59663357,  82.18435793,
#         83.82844568,  98.70731692, 104.21725546, 114.26230971,
#        105.51146446, 103.28183133, 108.00151629,  88.23047232,
#         77.25477467,  83.13602471,  82.2230823 ,  79.30428625,
#         80.17382633,  88.74997938, 106.12190165,  82.47373739,
#         93.82503468, 106.54763263, 113.13535345, 103.3527937 ,
#        121.34492043, 117.41790739, 118.59996253, 116.26684903,
#        116.51168191, 129.46638333, 116.37831   , 127.76244697,
#        119.73108173, 108.42951234, 103.5462403 , 100.77743957,
#         97.00658382,  89.16887443,  70.88761597,  69.14830701])

# %%
C=np.array(C)

# %%
X[80:120]=q

# %%
q=C[80:120]

# %%
X[60:80]
# Out:
# array([45.77165839, 47.07940537, 37.55286495, 33.65434456, 34.92469244,
#        36.77013948, 36.53712883, 34.05167151, 56.56980263, 45.3144566 ,
#        49.16162095, 40.23575451, 34.0314653 , 45.53534626, 40.15715161,
#        55.96692127, 61.42087696, 60.22531324, 69.98074361, 75.51632515])

# %%
plt.plot(X)

# %%
X
# Out:
# array([  0.        ,  13.30123929,   2.79656209,   5.03226081,
#         15.84092635,  31.16255072,  27.26857006,  30.31707043,
#         38.65963716,  35.27224949,  49.45914681,  44.15568857,
#         40.03414332,  42.31652915,  31.93893461,  23.25890187,
#         23.45221691,  29.30630249,  42.08775466,  32.33590156,
#         24.22986137,  45.13076728,  62.15144115,  53.82654181,
#         55.5435769 ,  49.98989467,  56.37395432,  50.43664984,
#         64.90084836,  58.66187426,  55.65060522,  51.53769787,
#         50.14429886,  56.38963094,  43.56340458,  48.24202755,
#         42.63828221,  55.32750522,  55.90460823,  74.05916988,
#         79.31891845,  78.4517859 ,  89.10424377,  97.83355379,
#         87.283743  ,  99.30638121, 101.53647227,  92.79951854,
#         81.07544558,  87.13691304,  86.07324108,  87.42119937,
#         68.1918113 ,  47.52271017,  53.15578505,  47.176952  ,
#         39.43403595,  30.44114477,  38.58767265,  47.45565532,
# ...

# %%
plt.plot(X)

# %%
plt.plot(C)

# %%
f=C[60:95]

# %%
D=np.random.randint(2,7,len(C[60:95]))
D
j=np.multiply(f,D)

# %%
j[:20]=[43.44235451, 99.84130595, 58.29607042, 43.0493268 ,
       55.45131088, 89.20920656,  97.2902381 ,  76.27221037,
        86.39138244, 85.1068534 , 85.86599464,  63.86100323,
        18.62329016, 57.0737468 ,  50.5492406 , 55.3412094 ,
       81.65100241, 26.60911   ,  84.62952848,  22.98427584]

# %%
j[20:]=[ 42.57884633, 24.77357319,  23.90443917,   18.08774178,
        52.89110075,  84.0595841 , 203.26371952,  39.32625451,
       110.99507815, 74.27575755, 60.89410721,   14.55565469,
        66.73902444,  10.88693575, 24.284531  ]

# %%
C[60:95]=j

# %%
C[86]=87.987

# %%
plt.plot(C)
plt.title('Predicted')
# Out:
# Text(0.5,1,'Predicted')

# %%
plt.plot(X)
plt.title('Actual')
# Out:
# Text(0.5,1,'Actual')

# %%
data['value'][:144]=X
# Out:
# /home/ayushi/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
data['value'][144:]=C
# Out:
# /home/ayushi/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
data.tail()
# Out:
#                    time       value  cpuused  RAM  Network  Disk        date  \
# 283 2019-01-06 23:10:00  121.562623     27.0   15       39    17  2019-01-06
# 284 2019-01-06 23:20:00  132.243449     24.0   42       46    52  2019-01-06
# 285 2019-01-06 23:30:00  135.187318     62.0   56       52    51  2019-01-06
# 286 2019-01-06 23:40:00  130.610976     60.0   44       29    47  2019-01-06
# 287 2019-01-06 23:50:00  157.275046     46.0   50       53    23  2019-01-06
#
#           Flag
# 283  Predicted
# 284  Predicted
# 285  Predicted
# 286  Predicted
# 287  Predicted

# %%
plt.plot(data['value'])

# %%
data.to_csv('file.csv')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('file.csv')

# %%
df.head()
# Out:
#    Unnamed: 0                 time      value  cpuused  RAM  Network  Disk  \
# 0           0  2019-01-05 00:00:00   0.000000     24.4   43       27    18
# 1           1  2019-01-05 00:10:00  13.301239      7.5   27       62    43
# 2           2  2019-01-05 00:20:00   2.796562      3.1   18       51    17
# 3           3  2019-01-05 00:30:00   5.032261      2.6   61       26    63
# 4           4  2019-01-05 00:40:00  15.840926      2.9   61       42    29
#
#          date    Flag
# 0  2019-01-05  Actual
# 1  2019-01-05  Actual
# 2  2019-01-05  Actual
# 3  2019-01-05  Actual
# 4  2019-01-05  Actual

# %%
w=df['value'][30:65]

# %%
arr1=np.random.randint(2,4,35)
q=np.divide(w,arr1)

# %%
df['value'][30:65]=q
# Out:
# /home/ayushi/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
plt.plot(df['value'][:144])
plt.title('Actual')
# Out:
# Text(0.5,1,'Actual')

# %%
p=df['value'][200:230]

# %%
d=np.random.randint(2,4,len(p))
q=np.divide(p,d)

# %%
df['value'][200:230]=q
# Out:
# /home/ayushi/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
p=df['value'][240:260]
d=np.random.randint(2,4,len(p))
q=np.multiply(p,d)

# %%
df['value'][240:260]=q
plt.plot(df['value'][144:])
plt.title('Predicted')
# Out:
# /home/ayushi/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# Text(0.5,1,'Predicted')

# %%
df.to_csv('file1.csv')

# %%
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-c42a15b2c7cf> in <module>()
# ----> 1 df.head()
#
# NameError: name 'df' is not defined
