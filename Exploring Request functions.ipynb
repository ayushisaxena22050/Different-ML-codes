# %%
import requests

# %%
r = requests.get('http://www.k-billing.com/example_invoices/professionalblue_example_tn.png')

# %%
from PIL import Image
from io import BytesIO

# %%
i = Image.open(BytesIO(r.content))

# %%
i
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=150x194 at 0x7F653F110F98>
